# %%
import pandas as pd
import sqlite3

df = pd.read_csv(r'C:\Users\admin\superstore-sales-analysis\data\superstore.csv\superstore.csv', encoding='utf-8')
df = df.rename(columns={'记录数': 'Record.Count'})

conn = sqlite3.connect('../data/superstore.db')
df.to_sql('sales', conn, if_exists='replace', index=False)

print("تم إنشاء قاعدة البيانات بنجاح")
# Out:
# تم إنشاء قاعدة البيانات بنجاح

# %%
# تأكد من أسماء الأعمدة في الجدول
result = pd.read_sql_query("SELECT * FROM sales LIMIT 5", conn)
print(result)
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  Record.Count               Order.Date        Order.ID  \
# 0       0.0     US             1  2011-01-07 00:00:00.000  CA-2011-130813
# 1       0.0     US             1  2011-01-21 00:00:00.000  CA-2011-148614
# 2       0.0     US             1  2011-08-05 00:00:00.000  CA-2011-118962
# 3       0.0     US             1  2011-08-05 00:00:00.000  CA-2011-118962
# 4       0.0     US             1  2011-09-29 00:00:00.000  CA-2011-146969
#
#    ... Sales   Segment                Ship.Date       Ship.Mode  \
# 0  ...    19  Consumer  2011-01-09 00:00:00.000    Second Class
# 1  ...    19  Consumer  2011-01-26 00:00:00.000  Standard Class
# 2  ...    21  Consumer  2011-08-09 00:00:00.000  Standard Class
# 3  ...   111  Consumer  2011-08-09 00:00:00.000  Standard Class
# 4  ...     6  Consumer  2011-10-03 00:00:00.000  Standard Class
#
#    Shipping.Cost       State  Sub.Category  Year        Market2 weeknum
# 0           4.37  California         Paper  2011  North America       2
# 1           0.94  California         Paper  2011  North America       4
# 2           1.81  California         Paper  2011  North America      32
# 3           4.59  California         Paper  2011  North America      32
# 4           1.32  California         Paper  2011  North America      40
#
# [5 rows x 27 columns]

# %%
query1 = """
SELECT "Category", "Sales", "Profit"
FROM sales
WHERE "Category" = 'Technology'
LIMIT 10
"""
result1 = pd.read_sql_query(query1, conn)
print(result1)
# Out:
#      Category  Sales  Profit
# 0  Technology   1471  264.60
# 1  Technology    294  108.57
# 2  Technology    201   62.16
# 3  Technology    698  209.34
# 4  Technology    185   44.46
# 5  Technology    389   23.24
# 6  Technology    345   72.36
# 7  Technology    450  184.32
# 8  Technology    955  257.60
# 9  Technology    280   44.82

# %%
query2 = """
SELECT "Category", SUM("Sales") as Total_Sales, SUM("Profit") as Total_Profit
FROM sales
GROUP BY "Category"
ORDER BY Total_Sales DESC
"""
result2 = pd.read_sql_query(query2, conn)
print(result2)
# Out:
#           Category  Total_Sales  Total_Profit
# 0       Technology      4744691  663778.73318
# 1        Furniture      4110884  285204.72380
# 2  Office Supplies      3787330  518473.83430

# %%
query3 = """
SELECT * 
FROM sales
WHERE "Category" = 'Furniture' 
  AND "Discount" > 0.3
"""
result3 = pd.read_sql_query(query3, conn)
print(result3)
print("\nعدد الصفوف:", len(result3))
# Out:
#        Category           City        Country Customer.ID     Customer.Name  \
# 0     Furniture    Saint-Denis         France   TC-209802      Tamara Chand
# 1     Furniture     Courbevoie         France   YC-218952    Yoseph Carroll
# 2     Furniture  Aubervilliers         France   DC-132852      Debra Catini
# 3     Furniture          Paris         France   ME-180102  Michelle Ellison
# 4     Furniture          Reims         France   HG-150252     Hunter Glantz
# ...         ...            ...            ...         ...               ...
# 2103  Furniture    Springfield  United States   JR-162104     Justin Ritter
# 2104  Furniture   Fort Collins  United States   AP-109154    Arthur Prichep
# 2105  Furniture    Springfield  United States   JK-160904     Juliana Krohn
# 2106  Furniture         Denver  United States   BS-113804      Bill Stewart
# 2107  Furniture         Parker  United States   TS-215054        Tony Sayre
#
#       Discount Market  Record.Count               Order.Date         Order.ID  \
# 0         0.35     EU             1  2012-11-10 00:00:00.000  ES-2012-5149849
# 1         0.35     EU             1  2013-05-09 00:00:00.000  ES-2013-5979288
# 2         0.35     EU             1  2014-05-01 00:00:00.000  IT-2014-5786031
# 3         0.35     EU             1  2014-08-06 00:00:00.000  IT-2014-2542510
# 4         0.60     EU             1  2011-01-26 00:00:00.000  ES-2011-4436456
# ...        ...    ...           ...                      ...              ...
# 2103      0.70     US             1  2014-09-20 00:00:00.000   CA-2014-143378
# 2104      0.70     US             1  2014-09-24 00:00:00.000   US-2014-132059
# 2105      0.70     US             1  2014-10-03 00:00:00.000   CA-2014-141117
# 2106      0.70     US             1  2014-12-03 00:00:00.000   US-2014-112347
# 2107      0.70     US             1  2014-12-20 00:00:00.000   CA-2014-116946
#
#       ... Sales    Segment                Ship.Date       Ship.Mode  \
# 0     ...  2012  Corporate  2012-11-13 00:00:00.000     First Class
# 1     ...   176  Corporate  2013-05-09 00:00:00.000        Same Day
# 2     ...   963   Consumer  2014-05-06 00:00:00.000    Second Class
# 3     ...  1630  Corporate  2014-08-08 00:00:00.000    Second Class
# 4     ...   119   Consumer  2011-01-26 00:00:00.000        Same Day
# ...   ...   ...        ...                      ...             ...
# 2103  ...    73  Corporate  2014-09-26 00:00:00.000  Standard Class
# 2104  ...   181   Consumer  2014-09-30 00:00:00.000  Standard Class
# 2105  ...   218   Consumer  2014-10-09 00:00:00.000  Standard Class
# 2106  ...   242  Corporate  2014-12-07 00:00:00.000  Standard Class
# 2107  ...   102   Consumer  2014-12-24 00:00:00.000  Standard Class
#
#       Shipping.Cost              State  Sub.Category  Year        Market2  \
# 0            232.54      Ile-de-France        Tables  2012             EU
# 1             44.62      Ile-de-France        Tables  2013             EU
# 2            139.90      Ile-de-France        Tables  2014             EU
# 3            148.41      Ile-de-France        Tables  2014             EU
# 4             24.75  Champagne-Ardenne     Bookcases  2011             EU
# ...             ...                ...           ...   ...            ...
# 2103           5.00             Oregon     Bookcases  2014  North America
# 2104          23.96           Colorado     Bookcases  2014  North America
# 2105          14.05             Oregon     Bookcases  2014  North America
# 2106          10.93           Colorado     Bookcases  2014  North America
# 2107           9.21           Colorado     Bookcases  2014  North America
#
#      weeknum
# 0         45
# 1         19
# 2         18
# 3         32
# 4          5
# ...      ...
# 2103      38
# 2104      39
# 2105      40
# 2106      49
# 2107      51
#
# [2108 rows x 27 columns]
#
# عدد الصفوف: 2108

# %%
query4 = """
SELECT 
    COUNT(*) as Total_Orders,
    SUM(CASE WHEN "Profit" < 0 THEN 1 ELSE 0 END) as Losing_Orders,
    AVG("Profit") as Average_Profit
FROM sales
WHERE "Category" = 'Furniture' 
  AND "Discount" > 0.3
"""
result4 = pd.read_sql_query(query4, conn)
print(result4)
# Out:
#    Total_Orders  Losing_Orders  Average_Profit
# 0          2108           1943     -142.458783

# %%
query5 = """
SELECT "Order.ID", "Category", "Profit"
FROM sales
WHERE "Profit" > (SELECT AVG("Profit") FROM sales)
LIMIT 10
"""
result5 = pd.read_sql_query(query5, conn)
print(result5)
# Out:
#          Order.ID         Category    Profit
# 0  CA-2011-118962  Office Supplies   53.2608
# 1  CA-2011-113579  Office Supplies   41.5104
# 2  CA-2012-105347  Office Supplies  180.7659
# 3  CA-2012-135545  Office Supplies   68.9631
# 4  CA-2012-135580  Office Supplies   31.5192
# 5  CA-2013-134803  Office Supplies   84.0512
# 6  CA-2013-123512  Office Supplies  107.7216
# 7  CA-2013-109365  Office Supplies  150.9840
# 8  CA-2013-109365  Office Supplies   56.9772
# 9  CA-2013-158694  Office Supplies   32.5008

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('../data/superstore.db')
print("تم الاتصال بقاعدة البيانات بنجاح")
# Out:
# تم الاتصال بقاعدة البيانات بنجاح

# %%
query6 = """
WITH avg_profit AS (
    SELECT AVG("Profit") as avg_p
    FROM sales
)
SELECT "Order.ID", "Category", "Profit"
FROM sales, avg_profit
WHERE "Profit" > avg_p
LIMIT 10
"""
result6 = pd.read_sql_query(query6, conn)
print(result6)
# Out:
#          Order.ID         Category    Profit
# 0  CA-2011-118962  Office Supplies   53.2608
# 1  CA-2011-113579  Office Supplies   41.5104
# 2  CA-2012-105347  Office Supplies  180.7659
# 3  CA-2012-135545  Office Supplies   68.9631
# 4  CA-2012-135580  Office Supplies   31.5192
# 5  CA-2013-134803  Office Supplies   84.0512
# 6  CA-2013-123512  Office Supplies  107.7216
# 7  CA-2013-109365  Office Supplies  150.9840
# 8  CA-2013-109365  Office Supplies   56.9772
# 9  CA-2013-158694  Office Supplies   32.5008

# %%
query7 = """
WITH category_margins AS (
    SELECT 
        "Category",
        SUM("Sales") as total_sales,
        SUM("Profit") as total_profit,
        (SUM("Profit") * 1.0 / SUM("Sales")) * 100 as profit_margin
    FROM sales
    GROUP BY "Category"
)
SELECT *
FROM category_margins
WHERE profit_margin < 10
"""
result7 = pd.read_sql_query(query7, conn)
print(result7)
# Out:
#     Category  total_sales  total_profit  profit_margin
# 0  Furniture      4110884   285204.7238       6.937795

# %%
query_region = """
WITH region_sales AS (
    SELECT 
        "Region",
        AVG("Sales") as avg_sales
    FROM sales
    GROUP BY "Region"
)
SELECT *
FROM region_sales
WHERE avg_sales > 250
"""
result_region = pd.read_sql_query(query_region, conn)
print(result_region)
# Out:
#            Region   avg_sales
# 0         Central  253.881353
# 1    Central Asia  367.597168
# 2           North  260.855172
# 3      North Asia  362.852438
# 4         Oceania  315.516777
# 5  Southeast Asia  282.658357
